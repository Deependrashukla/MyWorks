# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_excel("SelfShiksha_SLB_MCQ_80.xlsx")
df
# Out:
#      x            y
# 0    0    35.890078
# 1    1    89.450559
# 2    2    69.771869
# 3    3   103.359765
# 4    4   110.038149
# ..  ..          ...
# 95  95  2182.267303
# 96  96  2175.379681
# 97  97  2215.679556
# 98  98  2296.418676
# 99  99  2361.650562
#
# [100 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
x1 = [int(item) for item in list(df['x'])]
x2 = [num**2 for num in list(df['x'])]

df["x1"] = x1
df["x2"] = x2

df.drop(['x'], axis=1, inplace = True)

# %%
x = df.drop(['y'], axis=1)
y = df.y

reg = LinearRegression()
reg.fit(x,y)
# Out:
# LinearRegression()

# %%
print(reg.coef_, reg.intercept_)
# Out:
# [2.81439646 0.20414438] 70.5942688267537

# %%
# plt.scatter(x1,list(y))
plt.plot(x1,list(y))
